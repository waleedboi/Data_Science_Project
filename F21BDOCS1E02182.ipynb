# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
plt.rcParams["figure.figsize"]=[10,5]

df = pd.read_csv('/content/Student Attitude and Behavior.csv')

# %%
df.shape
# Out:
# (235, 19)

# %%
df.head()
# Out:
#   Certification Course  Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 0                   No    Male        BCA       100.0        58.0       79.0
# 1                   No  Female        BCA        90.0        40.0       70.0
# 2                  Yes    Male        BCA       159.0        78.0       71.0
# 3                  Yes  Female        BCA       147.0        20.0       70.0
# 4                   No    Male        BCA       170.0        54.0       40.0
#
#    12th Mark  college mark        hobbies daily studing time  \
# 0       64.0          80.0    Video Games      0 - 30 minute
# 1       80.0          70.0         Cinema     30 - 60 minute
# 2       61.0          55.0         Cinema         1 - 2 Hour
# 3       59.0          58.0  Reading books         1 - 2 Hour
# 4       65.0          30.0    Video Games     30 - 60 minute
#
#   prefer to study in  salary expectation Do you like your degree?  \
# 0            Morning               40000                       No
# 1            Morning               15000                      Yes
# 2            Anytime               13000                      Yes
# 3            Anytime             1500000                       No
# 4            Morning               50000                      Yes
#
#   willingness to pursue a career based on their degree   social medai & video  \
# 0                                                50%            1.30 - 2 hour
# 1                                                75%            1 - 1.30 hour
# 2                                                50%         More than 2 hour
# 3                                                50%            1.30 - 2 hour
# 4                                                25%            1.30 - 2 hour
#
#   Travelling Time  Stress Level  Financial Status part-time job
# 0  30 - 60 minutes           Bad              Bad            No
# 1   0 - 30 minutes           Bad              Bad            No
# 2  30 - 60 minutes         Awful              Bad            No
# 3   0 - 30 minutes           Bad             good            No
# 4  30 - 60 minutes          Good             good            No

# %%
df.tail()
# Out:
#     Certification Course  Gender Department  Height(CM)  Weight(KG)  \
# 230                  Yes    Male  B.com ISM       170.0        76.0
# 231                  Yes    Male  B.com ISM       172.0        52.0
# 232                  Yes  Female        BCA       139.0        33.0
# 233                  Yes  Female   Commerce       153.0        58.0
# 234                   No  Female  B.com ISM       155.0        39.0
#
#      10th Mark  12th Mark  college mark      hobbies daily studing time  \
# 230       72.0       67.0          65.0  Video Games     30 - 60 minute
# 231       72.0       70.0          76.0       Cinema         2 - 3 hour
# 232       90.0       75.0          70.0       Cinema     30 - 60 minute
# 233       85.0       74.0          75.0       Cinema      0 - 30 minute
# 234       45.0       45.0          50.0       Sports         3 - 4 hour
#
#     prefer to study in  salary expectation Do you like your degree?  \
# 230            Morning                7000                      Yes
# 231            Anytime               25000                      Yes
# 232              Night               20000                      Yes
# 233            Anytime               20000                      Yes
# 234              Night                  10                       No
#
#     willingness to pursue a career based on their degree    \
# 230                                                50%
# 231                                                75%
# 232                                                50%
# 233                                                75%
# 234                                                75%
#
#     social medai & video Travelling Time  Stress Level  Financial Status  \
# 230     More than 2 hour  30 - 60 minutes           Bad              Bad
# 231       30 - 60 Minute  30 - 60 minutes          Good             good
# 232       30 - 60 Minute    2.30 - 3 hour           Bad             good
# 233     More than 2 hour    2.30 - 3 hour         Awful             good
# 234       30 - 60 Minute    2.30 - 3 hour      fabulous             good
#
#     part-time job
# 230            No
# 231            No
# 232            No
# 233            No
# 234            No

# %%
df.dtypes
# Out:
# Certification Course                                       object
# Gender                                                     object
# Department                                                 object
# Height(CM)                                                float64
# Weight(KG)                                                float64
# 10th Mark                                                 float64
# 12th Mark                                                 float64
# college mark                                              float64
# hobbies                                                    object
# daily studing time                                         object
# prefer to study in                                         object
# salary expectation                                          int64
# Do you like your degree?                                   object
# willingness to pursue a career based on their degree       object
# social medai & video                                       object
# Travelling Time                                            object
# Stress Level                                               object
# Financial Status                                           object
# part-time job                                              object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Certification Course                                      0
# Gender                                                    0
# Department                                                0
# Height(CM)                                                0
# Weight(KG)                                                0
# 10th Mark                                                 0
# 12th Mark                                                 0
# college mark                                              0
# hobbies                                                   0
# daily studing time                                        0
# prefer to study in                                        0
# salary expectation                                        0
# Do you like your degree?                                  0
# willingness to pursue a career based on their degree      0
# social medai & video                                      0
# Travelling Time                                           0
# Stress Level                                              0
# Financial Status                                          0
# part-time job                                             0
# dtype: int64

# %%
df.describe()
# Out:
#        Height(CM)  Weight(KG)   10th Mark   12th Mark  college mark  \
# count  235.000000  235.000000  235.000000  235.000000    235.000000
# mean   157.402128   60.803830   76.848511   68.775872     70.660553
# std     21.510805   14.895844   13.047560   11.018192     15.727446
# min      4.500000   20.000000    7.400000   45.000000      1.000000
# 25%    152.000000   50.000000   70.000000   60.000000     60.000000
# 50%    160.000000   60.000000   80.000000   69.000000     70.000000
# 75%    170.000000   70.000000   86.250000   76.000000     80.000000
# max    192.000000  106.000000   98.000000   94.000000    100.000000
#
#        salary expectation
# count        2.350000e+02
# mean         3.248168e+04
# std          1.113146e+05
# min          0.000000e+00
# 25%          1.500000e+04
# 50%          2.000000e+04
# 75%          2.500000e+04
# max          1.500000e+06

# %%
df["Height(CM)"].describe()
# Out:
# count    235.000000
# mean     157.402128
# std       21.510805
# min        4.500000
# 25%      152.000000
# 50%      160.000000
# 75%      170.000000
# max      192.000000
# Name: Height(CM), dtype: float64

# %%
# to see specific row
df.iloc[50]
# Out:
# Certification Course                                                                Yes
# Gender                                                                             Male
# Department                                                B.com Accounting and Finance
# Height(CM)                                                                        153.0
# Weight(KG)                                                                         56.0
# 10th Mark                                                                          62.0
# 12th Mark                                                                          53.0
# college mark                                                                       80.0
# hobbies                                                                          Sports
# daily studing time                                                           1 - 2 Hour
# prefer to study in                                                              Morning
# salary expectation                                                                50000
# Do you like your degree?                                                            Yes
# willingness to pursue a career based on their degree                                75%
# social medai & video                                                     30 - 60 Minute
# Travelling Time                                                           2 - 2.30 hour
# Stress Level                                                                      Awful
# Financial Status                                                                  Awful
# part-time job                                                                       Yes
# Name: 50, dtype: object

# %%
# to see specific row
df.iloc[50:52]
# Out:
#    Certification Course  Gender                     Department  Height(CM)  \
# 50                  Yes    Male  B.com Accounting and Finance        153.0
# 51                  Yes  Female  B.com Accounting and Finance        157.0
#
#     Weight(KG)  10th Mark  12th Mark  college mark hobbies daily studing time  \
# 50        56.0       62.0       53.0          80.0  Sports         1 - 2 Hour
# 51        53.0       85.0       88.0          89.0  Sports         1 - 2 Hour
#
#    prefer to study in  salary expectation Do you like your degree?  \
# 50            Morning               50000                      Yes
# 51            Anytime                8000                      Yes
#
#    willingness to pursue a career based on their degree    \
# 50                                                75%
# 51                                               100%
#
#    social medai & video Travelling Time  Stress Level  Financial Status  \
# 50       30 - 60 Minute    2 - 2.30 hour         Awful            Awful
# 51             0 Minute    1 - 1.30 hour           Bad              Bad
#
#    part-time job
# 50           Yes
# 51            No

# %%
print(df.sort_values(by="Weight(KG)"))
# Out:
#     Certification Course  Gender Department  Height(CM)  Weight(KG)  \
# 3                    Yes  Female        BCA       147.0        20.0
# 210                  Yes  Female   Commerce       152.0        32.0
# 232                  Yes  Female        BCA       139.0        33.0
# 5                    Yes  Female        BCA       139.0        33.0
# 192                   No    Male  B.com ISM       149.0        35.0
# ..                   ...     ...        ...         ...         ...
# 77                   Yes    Male        BCA       172.0        91.0
# 183                  Yes    Male  B.com ISM       173.0        92.0
# 67                   Yes    Male        BCA       100.0        93.0
# 42                    No  Female   Commerce       159.0        95.0
# 163                  Yes    Male   Commerce       190.0       106.0
#
#      10th Mark  12th Mark  college mark        hobbies daily studing time  \
# 3         70.0       59.0          58.0  Reading books         1 - 2 Hour
# 210       80.0       60.0          70.0         Sports         1 - 2 Hour
# 232       90.0       75.0          70.0         Cinema     30 - 60 minute
# 5         90.0       75.0          70.0         Cinema     30 - 60 minute
# 192       70.0       67.0          65.0    Video Games         1 - 2 Hour
# ..         ...        ...           ...            ...                ...
# 77        92.0       69.0          85.0         Cinema         1 - 2 Hour
# 183       54.0       65.0           2.0         Cinema      0 - 30 minute
# 67        90.0       62.0          79.0  Reading books     30 - 60 minute
# 42        72.0       80.0          79.0         Cinema      0 - 30 minute
# 163       82.0       78.0          80.0  Reading books         1 - 2 Hour
#
#     prefer to study in  salary expectation Do you like your degree?  \
# 3              Anytime             1500000                       No
# 210              Night                  15                      Yes
# 232              Night               20000                      Yes
# 5                Night               20000                      Yes
# 192            Anytime               15000                      Yes
# ..                 ...                 ...                      ...
# 77               Night               15000                      Yes
# 183            Anytime               23000                      Yes
# 67               Night               18000                      Yes
# 42             Anytime               10000                      Yes
# 163            Anytime               25000                      Yes
#
#     willingness to pursue a career based on their degree    \
# 3                                                  50%
# 210                                                75%
# 232                                                50%
# 5                                                  50%
# 192                                               100%
# ..                                                 ...
# 77                                                 75%
# 183                                               100%
# 67                                                 75%
# 42                                                 50%
# 163                                               100%
#
#     social medai & video Travelling Time  Stress Level  Financial Status  \
# 3          1.30 - 2 hour   0 - 30 minutes           Bad             good
# 210        1 - 1.30 hour  30 - 60 minutes           Bad             good
# 232       30 - 60 Minute    2.30 - 3 hour           Bad             good
# 5         30 - 60 Minute   0 - 30 minutes           Bad             good
# 192        1 - 30 Minute   0 - 30 minutes          Good             good
# ..                   ...              ...           ...              ...
# 77         1 - 1.30 hour    1 - 1.30 hour          Good             good
# 183     More than 2 hour    1 - 1.30 hour          Good             good
# 67        30 - 60 Minute  30 - 60 minutes           Bad              Bad
# 42      More than 2 hour   0 - 30 minutes          Good             good
# 163        1 - 30 Minute    1.30 - 2 hour          Good              Bad
#
#     part-time job
# 3              No
# 210            No
# 232            No
# 5              No
# 192            No
# ..            ...
# 77             No
# 183            No
# 67             No
# 42             No
# 163           Yes
#
# [235 rows x 19 columns]

# %%
print(df.sort_values(by="Weight(KG)",ascending=False))
# Out:
#     Certification Course  Gender Department  Height(CM)  Weight(KG)  \
# 163                  Yes    Male   Commerce       190.0       106.0
# 42                    No  Female   Commerce       159.0        95.0
# 67                   Yes    Male        BCA       100.0        93.0
# 183                  Yes    Male  B.com ISM       173.0        92.0
# 77                   Yes    Male        BCA       172.0        91.0
# ..                   ...     ...        ...         ...         ...
# 41                    No  Female        BCA        98.0        35.0
# 5                    Yes  Female        BCA       139.0        33.0
# 232                  Yes  Female        BCA       139.0        33.0
# 210                  Yes  Female   Commerce       152.0        32.0
# 3                    Yes  Female        BCA       147.0        20.0
#
#      10th Mark  12th Mark  college mark        hobbies daily studing time  \
# 163       82.0       78.0          80.0  Reading books         1 - 2 Hour
# 42        72.0       80.0          79.0         Cinema      0 - 30 minute
# 67        90.0       62.0          79.0  Reading books     30 - 60 minute
# 183       54.0       65.0           2.0         Cinema      0 - 30 minute
# 77        92.0       69.0          85.0         Cinema         1 - 2 Hour
# ..         ...        ...           ...            ...                ...
# 41        70.0       55.0          70.0  Reading books         1 - 2 Hour
# 5         90.0       75.0          70.0         Cinema     30 - 60 minute
# 232       90.0       75.0          70.0         Cinema     30 - 60 minute
# 210       80.0       60.0          70.0         Sports         1 - 2 Hour
# 3         70.0       59.0          58.0  Reading books         1 - 2 Hour
#
#     prefer to study in  salary expectation Do you like your degree?  \
# 163            Anytime               25000                      Yes
# 42             Anytime               10000                      Yes
# 67               Night               18000                      Yes
# 183            Anytime               23000                      Yes
# 77               Night               15000                      Yes
# ..                 ...                 ...                      ...
# 41               Night               20000                      Yes
# 5                Night               20000                      Yes
# 232              Night               20000                      Yes
# 210              Night                  15                      Yes
# 3              Anytime             1500000                       No
#
#     willingness to pursue a career based on their degree    \
# 163                                               100%
# 42                                                 50%
# 67                                                 75%
# 183                                               100%
# 77                                                 75%
# ..                                                 ...
# 41                                                 75%
# 5                                                  50%
# 232                                                50%
# 210                                                75%
# 3                                                  50%
#
#     social medai & video Travelling Time  Stress Level  Financial Status  \
# 163        1 - 30 Minute    1.30 - 2 hour          Good              Bad
# 42      More than 2 hour   0 - 30 minutes          Good             good
# 67        30 - 60 Minute  30 - 60 minutes           Bad              Bad
# 183     More than 2 hour    1 - 1.30 hour          Good             good
# 77         1 - 1.30 hour    1 - 1.30 hour          Good             good
# ..                   ...              ...           ...              ...
# 41         1.30 - 2 hour  30 - 60 minutes          Good             good
# 5         30 - 60 Minute   0 - 30 minutes           Bad             good
# 232       30 - 60 Minute    2.30 - 3 hour           Bad             good
# 210        1 - 1.30 hour  30 - 60 minutes           Bad             good
# 3          1.30 - 2 hour   0 - 30 minutes           Bad             good
#
#     part-time job
# 163           Yes
# 42             No
# 67             No
# 183            No
# 77             No
# ..            ...
# 41             No
# 5              No
# 232            No
# 210            No
# 3              No
#
# [235 rows x 19 columns]

# %%
Q1=df["college mark"].quantile(0.25)
Q2=df["college mark"].quantile(0.50)
Q3=df["college mark"].quantile(0.75)
IQR=Q3-Q1
IQR
# Out:
# 20.0

# %%
# pre processing
df.isnull()
# Out:
#      Certification Course  Gender  Department  Height(CM)  Weight(KG)  \
# 0                   False   False       False       False       False
# 1                   False   False       False       False       False
# 2                   False   False       False       False       False
# 3                   False   False       False       False       False
# 4                   False   False       False       False       False
# ..                    ...     ...         ...         ...         ...
# 230                 False   False       False       False       False
# 231                 False   False       False       False       False
# 232                 False   False       False       False       False
# 233                 False   False       False       False       False
# 234                 False   False       False       False       False
#
#      10th Mark  12th Mark  college mark  hobbies  daily studing time  \
# 0        False      False         False    False               False
# 1        False      False         False    False               False
# 2        False      False         False    False               False
# 3        False      False         False    False               False
# 4        False      False         False    False               False
# ..         ...        ...           ...      ...                 ...
# 230      False      False         False    False               False
# 231      False      False         False    False               False
# 232      False      False         False    False               False
# 233      False      False         False    False               False
# 234      False      False         False    False               False
#
#      prefer to study in  salary expectation  Do you like your degree?  \
# 0                 False               False                     False
# 1                 False               False                     False
# 2                 False               False                     False
# 3                 False               False                     False
# 4                 False               False                     False
# ..                  ...                 ...                       ...
# 230               False               False                     False
# 231               False               False                     False
# 232               False               False                     False
# 233               False               False                     False
# 234               False               False                     False
#
#      willingness to pursue a career based on their degree    \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 230                                              False
# 231                                              False
# 232                                              False
# 233                                              False
# 234                                              False
#
#      social medai & video  Travelling Time   Stress Level   Financial Status  \
# 0                   False             False          False             False
# 1                   False             False          False             False
# 2                   False             False          False             False
# 3                   False             False          False             False
# 4                   False             False          False             False
# ..                    ...               ...            ...               ...
# 230                 False             False          False             False
# 231                 False             False          False             False
# 232                 False             False          False             False
# 233                 False             False          False             False
# 234                 False             False          False             False
#
#      part-time job
# 0            False
# 1            False
# 2            False
# 3            False
# 4            False
# ..             ...
# 230          False
# 231          False
# 232          False
# 233          False
# 234          False
#
# [235 rows x 19 columns]

# %%
# missing values
print(df.isnull().sum())
# Out:
# Certification Course                                      0
# Gender                                                    0
# Department                                                0
# Height(CM)                                                0
# Weight(KG)                                                0
# 10th Mark                                                 0
# 12th Mark                                                 0
# college mark                                              0
# hobbies                                                   0
# daily studing time                                        0
# prefer to study in                                        0
# salary expectation                                        0
# Do you like your degree?                                  0
# willingness to pursue a career based on their degree      0
# social medai & video                                      0
# Travelling Time                                           0
# Stress Level                                              0
# Financial Status                                          0
# part-time job                                             0
# dtype: int64

# %%
sns.histplot(df['Do you like your degree?'],kde=False)
plt.show()

# %%
old_names = ['Certification Course', 'Gender', 'Department', 'Height(CM)',
       'Weight(KG)', '10th Mark', '12th Mark', 'college mark', 'hobbies',
       'daily studing time', 'prefer to study in', 'salary expectation',
       'Do you like your degree?',
       'willingness to pursue a career based on their degree  ',
       'social medai & video', 'Travelling Time ', 'Stress Level ',
       'Financial Status', 'part-time job']

new_names = ['Certification_Course', 'Gender', 'Department', 'Height(CM)',
       'Weight(KG)', '10th_Mark', '12th_Mark', 'college_mark', 'hobbies',
       'daily_studing_time', 'prefer_to_study_in', 'salary_expectation',
       'Do_you_like_your_degree?',
       'willingness_to_pursue_a_career_based_on_their_degree',
       'social_medai_&_video', 'Travelling_Time', 'Stress_Level',
       'Financial_Status', 'part-time_job']

df.rename(columns=dict(zip(old_names, new_names)), inplace=True)
df.columns
# Out:
# Index(['Certification_Course', 'Gender', 'Department', 'Height(CM)',
#        'Weight(KG)', '10th_Mark', '12th_Mark', 'college_mark', 'hobbies',
#        'daily_studing_time', 'prefer_to_study_in', 'salary_expectation',
#        'Do_you_like_your_degree?',
#        'willingness_to_pursue_a_career_based_on_their_degree',
#        'social_medai_&_video', 'Travelling_Time', 'Stress_Level',
#        'Financial_Status', 'part-time_job'],
#       dtype='object')

# %%
# females are generally doing better than their male counterparts

df.groupby('Gender')[['Height(CM)','Weight(KG)',
                     '10th_Mark', '12th_Mark', 'college_mark']].mean()
# Out:
#         Height(CM)  Weight(KG)  10th_Mark  12th_Mark  college_mark
# Gender
# Female  150.348101   50.468354  78.974684  71.715190     76.870886
# Male    160.974359   66.037821  75.771795  67.287372     67.515577

# %%
df.groupby(['Gender'])[['Gender']].value_counts().plot(kind='pie',autopct='%1.1f%%',ylabel="")
plt.title('Gender Distribution')
# Out:
# Text(0.5, 1.0, 'Gender Distribution')

# %%
# How is stress imparting performance?
df.groupby('Stress_Level')[['Gender']].value_counts()
# Out:
# Stress_Level  Gender
# Awful         Male      14
#               Female     5
# Bad           Male      45
#               Female    23
# Good          Male      89
#               Female    48
# fabulous      Male       8
#               Female     3
# Name: count, dtype: int64

# %%
df.groupby('Stress_Level')[['Gender']].value_counts().plot(kind='pie',autopct='%1.1f%%',ylabel="")
plt.title('Stress Distribution among Gender')
# Out:
# Text(0.5, 1.0, 'Stress Distribution among Gender')

# %%
df.groupby('part-time_job')[['Gender']].value_counts().plot(kind='pie',autopct='%1.1f%%',ylabel="")
plt.title('Gender participation in Part-time Job')
# More Males are engaged in part-time job
# Out:
# Text(0.5, 1.0, 'Gender participation in Part-time Job')

# %%
df['Stress_Level'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Stress_Level'>

# %%
df.groupby(['Stress_Level', 'Gender'])[['10th_Mark']].mean().plot(kind='bar')
plt.title('Stress vr Performance')
# Out:
# Text(0.5, 1.0, 'Stress vr Performance')

# %%
numCols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
df[numCols].corr()
# Out:
#                     Height(CM)  Weight(KG)  10th_Mark  12th_Mark  \
# Height(CM)            1.000000    0.275948   0.019938  -0.119618
# Weight(KG)            0.275948    1.000000   0.062977  -0.019133
# 10th_Mark             0.019938    0.062977   1.000000   0.473254
# 12th_Mark            -0.119618   -0.019133   0.473254   1.000000
# college_mark         -0.018535   -0.014901   0.465861   0.424828
# salary_expectation   -0.010708   -0.087787  -0.055794  -0.085623
#
#                     college_mark  salary_expectation
# Height(CM)             -0.018535           -0.010708
# Weight(KG)             -0.014901           -0.087787
# 10th_Mark               0.465861           -0.055794
# 12th_Mark               0.424828           -0.085623
# college_mark            1.000000           -0.103034
# salary_expectation     -0.103034            1.000000

# %% [markdown]
# Final Report
# Kids who do well in grade school generally do well in college
# Females generally do better accademically than the males
# Females perform better under stress than the males, on the other hand, Males do better when they are happy.
# Students turn to social Media and videos when they are stressed

# %%
sns.heatmap(data=df[numCols].corr(), annot=True)
plt.title('Correlation Map')
# Out:
# Text(0.5, 1.0, 'Correlation Map')

# %%
sns.lmplot(data=df[['10th_Mark','12th_Mark']],x='12th_Mark', y='10th_Mark')
plt.title('10th vs 12th Grade Mark')
# Out:
# Text(0.5, 1.0, '10th vs 12th Grade Mark')

# %%
# Final Report

# Kids who do well in grade school generally do well in college
# Females generally do better accademically than the males
# Females perform better under stress than the males, on the other hand, Males do better when they are happy.
# Students turn to social Media and videos when they are stressed
